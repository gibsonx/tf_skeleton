# %% [markdown]
# <a href="https://colab.research.google.com/github/gibsonx/tf_skeleton/blob/master/tf_keypoint_colab_densenet121.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#!git clone https://github.com/gibsonx/tf_skeleton.git

# %%
#!pip install -r /content/tf_skeleton/requirements.txt > /dev/null

# %%
from pycocotools.coco import COCO
import numpy as np
np.bool=bool
import os.path
from typing import Any, Callable, List, Optional, Tuple
from PIL import Image
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os, json, cv2, numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import keras

import tensorflow as tf
print(tf.__version__)

from keras.models import Sequential,Model

from keras.layers import (
    Flatten,
    Dense,
    Dropout,
    Conv2D,
    LeakyReLU,
    BatchNormalization,
    MaxPool2D,
    GlobalAveragePooling2D,
)
from imgaug import augmenters as iaa
import imgaug as ia
import imageio
from keras.applications import ResNet50
from keras.applications.densenet import DenseNet121
from imgaug.augmentables.kps import Keypoint, KeypointsOnImage
import math
# Out:
# 2.17.1

# %%
train_img_dir="/content/drive/MyDrive/Dataset/aspine20230930/image_train"
val_img_dir="/content/drive/MyDrive/Dataset/aspine20230930/image_val"
val_annotations_file="/content/drive/MyDrive/Dataset/aspine20230930/annotations/person_keypoints_Validation.json"
train_annotations_file="/content/drive/MyDrive/Dataset/aspine20230930/annotations/person_keypoints_Train.json"

# %%
class DataframeMaker():

  def __init__(self,img_path,annotations_file, img_height, img_width):
      self.img_path = img_path
      self.coco = COCO(annotations_file)
      self.imgIds = self.coco.getImgIds()
      self.dataframe = None
      self.__coco_build__()
      self.img_height = img_height
      self.img_width = img_width
      if self.img_width and self.img_height:
          self.resize_dataset()
          print ("image size has been set to %d x %d" % (self.img_height, self.img_width))
      else:
          print ("image keeps as original size")

  def __coco_build__(self):
      """
      read annotation and build dataframe
      :return:
      """
      kps_metrix = []

      for id in self.imgIds:

        # load a image
        img = self.coco.loadImgs(id)[0]
        imgPath = img['file_name']

        ann=self.coco.loadAnns(self.coco.getAnnIds(imgIds=img['id']))

        keypoints_original = [[list(a) for a in zip(*[iter(ann[0]['keypoints'])]*3)]]

        kps_row = []
        for kp in keypoints_original:
            for el in kp:
                kps_row.extend(el[0:2])
        kps_row.append(imgPath)

        kps_metrix.append(kps_row)



      df = pd.DataFrame(kps_metrix)

      self.dataframe = df

  def resize_dataset(self):
    """
    :param img_height:
    :param img_width:
    :return:
    """
    ts_kps_metrix = []
    ts_image_list = []

    for index, row in self.dataframe.iterrows():


      image = row[-1:].item()
      fullImgPath = os.path.join(self.img_path,image)
      open_cv_image = np.array(Image.open(fullImgPath))

      annotations = row[:32]
      converted_keypoints = [list(a) for a in zip(*[iter(annotations)]*2)]

      kps = [Keypoint(x=coodination[0], y=coodination[1]) for coodination in converted_keypoints]
      kpsoi = KeypointsOnImage(kps, shape=open_cv_image.shape)

      ia.seed(1)

      seq = iaa.Sequential([
          iaa.Crop(px=(32, 32, 32, 32)),
          iaa.Resize({"height": self.img_height , "width": self.img_width})
      ])

      image_aug, kpsoi_aug = seq(image=open_cv_image, keypoints=kpsoi)

      ts_kps_row = []

      image_height, image_width = image_aug.shape[:2]

      for i in range(len(kpsoi_aug.keypoints)):
          after = kpsoi_aug.keypoints[i]
          x = max(0, min(after.x, image_width - 1))  # Clamp x between 0 and image_width - 1
          y = max(0, min(after.y, image_height - 1))  # Clamp y between 0 and image_height - 1
          ts_kps_row.extend([x, y])

      ts_kps_metrix.append(ts_kps_row)
      ts_image_list.append(image_aug)

    df = pd.DataFrame(ts_kps_metrix)

    df['image'] = ts_image_list

    self.dataframe = df

class DataGenerator(tf.keras.utils.Sequence):

  def __init__(self, dataframe, batch_size, arguement = False):
      self.df = dataframe
      self.batch_size = batch_size
      self.argument = arguement

  def __len__(self):
      return math.ceil(len(self.df) / self.batch_size)

  def __getitem__(self, idx):
      low = idx * self.batch_size
      # Cap upper bound at array length; the last batch may be smaller
      # if the total number of items is not a multiple of batch size.
      high = min(low + self.batch_size, len(self.df))
      images = self.df.loc[low:high,'image']
      annotations = self.df.loc[low:high,:31]

      if self.argument:
          return self.data_arguement(images, annotations)
      else:
          return np.stack(images), annotations.to_numpy()

  def on_epoch_end(self):
      print("shuffle")
      self.df = self.df.sample(frac=1, random_state=41).reset_index(drop=True)

  def data_arguement(self, images, annotations):

      ia.seed(3)
      seq = iaa.Sequential([
            iaa.Sometimes(
              0.5,
              iaa.SomeOf((1, 3), [
              iaa.Affine(
                  rotate=(-8,8)
                  ),
              iaa.LinearContrast((0.4, 1.2)),
              iaa.AdditiveGaussianNoise(loc=0, scale=(0.0, 0.05*255), per_channel=0.5),
              ])
            )
          ])

      images_aug, points_aug = seq(images=images, keypoints=self.kpslist_to_tuple(annotations))
      kps_list = self.kpstuple_to_list(points_aug)

      return np.stack(images_aug), np.stack(kps_list)

  def kpslist_to_tuple(self,annotations):
      kpstuple = []

      for index, row in annotations.iterrows():
          converted_keypoints = [list(a) for a in zip(*[iter(row)]*2)]
          kps = [Keypoint(x=coodination[0], y=coodination[1]) for coodination in converted_keypoints]
          kpstuple.append(kps)

      return kpstuple

  def kpstuple_to_list(self,kps_tuple):
      kpslist = []

      for kpsoi in kps_tuple:
          ts_kps_row = []
          for i in range(len(kpsoi)):
              # print(kpsoi_aug[i].is_out_of_image(image=images_aug[i]))
              ts_kps_row.extend([kpsoi[i].x,kpsoi[i].y])
          kpslist.append(ts_kps_row)

      return kpslist

# %%
height = 500
width = 280

val_df = DataframeMaker(val_img_dir,val_annotations_file,height,width)
train_df = DataframeMaker(train_img_dir,train_annotations_file,height,width)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# image size has been set to 500 x 280
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# image size has been set to 500 x 280

# %%
batch_size=16

val_generator = DataGenerator(val_df.dataframe,batch_size,False)
train_generator = DataGenerator(train_df.dataframe,batch_size,False)

# %%
def show_image(image, kps, image_path):

    fullImgPath = os.path.join(image_path,image)
    open_cv_image = np.array(Image.open(fullImgPath))
    converted_keypoints = [list(a) for a in zip(*[iter(kps)]*2)]

    kps = [Keypoint(x=coodination[0], y=coodination[1]) for coodination in converted_keypoints]

    kpsoi = KeypointsOnImage(kps, shape=open_cv_image.shape)

    image_with_kps = kpsoi.draw_on_image(open_cv_image, size=15)

    plt.imshow(image_with_kps)

def show_tran_image(image, kps):

    open_cv_image = np.array(image)
    converted_keypoints = [list(a) for a in zip(*[iter(kps)]*2)]

    kps = [Keypoint(x=coodination[0], y=coodination[1]) for coodination in converted_keypoints]

    kpsoi = KeypointsOnImage(kps, shape=open_cv_image.shape)

    image_with_kps = kpsoi.draw_on_image(open_cv_image, size=5)

    plt.imshow(image_with_kps)

# %% [markdown]
# Visualize a simple image

# %% [markdown]
# Validation Dataset Sample

# %%
rand_number = np.random.randint(0,len(val_df.dataframe))
X, Y = val_df.dataframe.loc[rand_number][-1:].item(),val_df.dataframe.loc[rand_number][0:32],
show_tran_image(X,Y)

# %% [markdown]
# Train Dataset Sample

# %%
X_batch, y_batch= train_generator[0]

# %%
rand_number = np.random.randint(0,len(X_batch))
X, Y = X_batch[rand_number],y_batch[rand_number][:32],
show_tran_image(X,Y)

# %% [markdown]
# Build Model

# %%
model = tf.keras.models.Sequential()
pretrained_model = DenseNet121(input_shape=(height,width,3), include_top=False)
pretrained_model.trainable = True

model.add(pretrained_model)
model.add(Flatten())
model.add(Dense(1024, activation='relu'))  #increase the number of neurons
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))  #increase the number of neurons
model.add(Dropout(0.2))
model.add(Dense(32))  # Yet another dense layer
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ densenet121 (Functional)             │ (None, 15, 8, 1024)         │       7,037,504 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 122880)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1024)                │     125,830,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         524,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 32)                  │          16,416 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 133,408,864 (508.91 MB)
#  Trainable params: 133,325,216 (508.60 MB)
#  Non-trainable params: 83,648 (326.75 KB)

# %%
# tf.keras.utils.plot_model(model, show_shapes=True)

# %%
Adam=tf.keras.optimizers.Adam(learning_rate=1e-5, amsgrad=False)

model.compile(optimizer=Adam,loss='mean_squared_error',metrics=['mae'])

# %%
epoch_num = 400

checkpoint_path = "/content/drive/MyDrive/Dataset/aspine20241201.weights.h5"
checkpoint_dir = os.path.dirname(checkpoint_path)

model.load_weights(checkpoint_path)

# callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                          save_best_only=True,
                          save_freq='epoch',
                          save_weights_only=True,
                          verbose=1)

# callback that reduces learning rate when val_loss doesn't improve in 5 epoches
# reduce_lr_callback = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', factor=0.2, patience=3, min_lr=0.01)

history = model.fit(train_generator,
            validation_data=val_generator,
            epochs=epoch_num,
            callbacks=[cp_callback,])
# Out:
# Epoch 1/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - loss: 681.2950 - mae: 20.7982shuffle
# shuffle
#
# Epoch 1: val_loss improved from inf to 59.88000, saving model to /content/drive/MyDrive/Dataset/aspine20241201.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 679.6976 - mae: 20.7719 - val_loss: 59.8800 - val_mae: 6.0554
# Epoch 2/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - loss: 611.8994 - mae: 19.7459shuffle
# shuffle
#
# Epoch 2: val_loss improved from 59.88000 to 45.77316, saving model to /content/drive/MyDrive/Dataset/aspine20241201.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 612.1179 - mae: 19.7489 - val_loss: 45.7732 - val_mae: 5.2616
# Epoch 3/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - loss: 653.4141 - mae: 20.3739shuffle
# shuffle
#
# Epoch 3: val_loss improved from 45.77316 to 33.72350, saving model to /content/drive/MyDrive/Dataset/aspine20241201.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - loss: 656.0885 - mae: 20.4112 - val_loss: 33.7235 - val_mae: 4.5173
# Epoch 4/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - loss: 679.2850 - mae: 20.6734shuffle
# shuffle
#
# Epoch 4: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 408ms/step - loss: 678.4171 - mae: 20.6658 - val_loss: 39.7755 - val_mae: 4.9522
# Epoch 5/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - loss: 629.6092 - mae: 19.8979shuffle
# shuffle
#
# Epoch 5: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 410ms/step - loss: 630.8126 - mae: 19.9118 - val_loss: 55.6009 - val_mae: 5.9081
# Epoch 6/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - loss: 672.0907 - mae: 20.4904shuffle
# shuffle
#
# Epoch 6: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 409ms/step - loss: 671.9135 - mae: 20.5003 - val_loss: 43.8850 - val_mae: 5.1835
# Epoch 7/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - loss: 685.3788 - mae: 20.7156shuffle
# shuffle
#
# Epoch 7: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 412ms/step - loss: 683.2731 - mae: 20.6865 - val_loss: 54.4840 - val_mae: 5.8200
# Epoch 8/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - loss: 630.8181 - mae: 19.8346shuffle
# shuffle
#
# Epoch 8: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 412ms/step - loss: 630.8588 - mae: 19.8395 - val_loss: 39.1352 - val_mae: 4.9429
# Epoch 9/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - loss: 665.1127 - mae: 20.3844shuffle
# shuffle
#
# Epoch 9: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 424ms/step - loss: 666.4176 - mae: 20.4065 - val_loss: 51.3593 - val_mae: 5.6748
# Epoch 10/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - loss: 636.9810 - mae: 20.1345shuffle
# shuffle
#
# Epoch 10: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 415ms/step - loss: 638.0757 - mae: 20.1537 - val_loss: 60.3318 - val_mae: 6.1566
# Epoch 11/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - loss: 658.5543 - mae: 20.3105shuffle
# shuffle
#
# Epoch 11: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 415ms/step - loss: 658.6442 - mae: 20.3120 - val_loss: 90.2127 - val_mae: 7.6399
# Epoch 12/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - loss: 715.9315 - mae: 21.2082shuffle
# shuffle
#
# Epoch 12: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 418ms/step - loss: 714.2413 - mae: 21.1875 - val_loss: 52.6879 - val_mae: 5.7314
# Epoch 13/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - loss: 711.3693 - mae: 20.9166shuffle
# shuffle
#
# Epoch 13: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 415ms/step - loss: 710.7368 - mae: 20.9219 - val_loss: 39.6639 - val_mae: 4.9550
# Epoch 14/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - loss: 633.3567 - mae: 19.9413shuffle
# shuffle
#
# Epoch 14: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 419ms/step - loss: 633.2129 - mae: 19.9465 - val_loss: 43.2216 - val_mae: 5.1976
# Epoch 15/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - loss: 662.8575 - mae: 20.5230shuffle
# shuffle
#
# Epoch 15: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 417ms/step - loss: 664.2855 - mae: 20.5373 - val_loss: 43.0732 - val_mae: 5.1504
# Epoch 16/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - loss: 665.8346 - mae: 20.4664shuffle
# shuffle
#
# Epoch 16: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 419ms/step - loss: 665.1762 - mae: 20.4568 - val_loss: 86.0575 - val_mae: 7.5329
# Epoch 17/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - loss: 583.6589 - mae: 19.0480shuffle
# shuffle
#
# Epoch 17: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 417ms/step - loss: 585.1080 - mae: 19.0792 - val_loss: 35.9558 - val_mae: 4.7189
# Epoch 18/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - loss: 588.5707 - mae: 19.2779shuffle
# shuffle
#
# Epoch 18: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 419ms/step - loss: 590.5626 - mae: 19.3074 - val_loss: 71.1181 - val_mae: 6.7724
# Epoch 19/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - loss: 605.0779 - mae: 19.5608shuffle
# shuffle
#
# Epoch 19: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 420ms/step - loss: 609.0226 - mae: 19.6170 - val_loss: 51.9802 - val_mae: 5.6684
# Epoch 20/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - loss: 598.1870 - mae: 19.5608shuffle
# shuffle
#
# Epoch 20: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 420ms/step - loss: 598.0544 - mae: 19.5546 - val_loss: 73.2294 - val_mae: 6.8744
# Epoch 21/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - loss: 626.8805 - mae: 19.8882shuffle
# shuffle
#
# Epoch 21: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 420ms/step - loss: 627.1904 - mae: 19.8902 - val_loss: 72.0153 - val_mae: 6.8796
# Epoch 22/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - loss: 611.5235 - mae: 19.5425shuffle
# shuffle
#
# Epoch 22: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 429ms/step - loss: 612.2983 - mae: 19.5533 - val_loss: 39.8346 - val_mae: 4.9673
# Epoch 23/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - loss: 636.7581 - mae: 19.9527shuffle
# shuffle
#
# Epoch 23: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 422ms/step - loss: 638.8232 - mae: 19.9767 - val_loss: 50.0628 - val_mae: 5.5760
# Epoch 24/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - loss: 647.7466 - mae: 20.2621shuffle
# shuffle
#
# Epoch 24: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 423ms/step - loss: 648.6828 - mae: 20.2663 - val_loss: 77.2734 - val_mae: 6.9587
# Epoch 25/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - loss: 679.4825 - mae: 20.6392shuffle
# shuffle
#
# Epoch 25: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 430ms/step - loss: 678.6904 - mae: 20.6213 - val_loss: 128.6799 - val_mae: 9.2069
# Epoch 26/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - loss: 648.9067 - mae: 20.1897shuffle
# shuffle
#
# Epoch 26: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 432ms/step - loss: 648.8047 - mae: 20.1910 - val_loss: 48.9215 - val_mae: 5.4620
# Epoch 27/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - loss: 634.3536 - mae: 20.0048shuffle
# shuffle
#
# Epoch 27: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 423ms/step - loss: 633.6860 - mae: 19.9911 - val_loss: 74.0011 - val_mae: 6.7473
# Epoch 28/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - loss: 634.4384 - mae: 19.9225shuffle
# shuffle
#
# Epoch 28: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 424ms/step - loss: 635.7109 - mae: 19.9459 - val_loss: 68.2825 - val_mae: 6.5124
# Epoch 29/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - loss: 620.0432 - mae: 19.6180shuffle
# shuffle
#
# Epoch 29: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 426ms/step - loss: 622.3433 - mae: 19.6593 - val_loss: 54.1442 - val_mae: 5.7496
# Epoch 30/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - loss: 624.1625 - mae: 19.8539shuffle
# shuffle
#
# Epoch 30: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 425ms/step - loss: 624.1028 - mae: 19.8468 - val_loss: 35.1022 - val_mae: 4.6534
# Epoch 31/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - loss: 631.7868 - mae: 19.7698shuffle
# shuffle
#
# Epoch 31: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 426ms/step - loss: 632.2676 - mae: 19.7865 - val_loss: 34.9277 - val_mae: 4.6473
# Epoch 32/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - loss: 709.5339 - mae: 21.1733shuffle
# shuffle
#
# Epoch 32: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 425ms/step - loss: 706.2902 - mae: 21.1140 - val_loss: 45.8045 - val_mae: 5.4058
# Epoch 33/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - loss: 710.8698 - mae: 20.9494shuffle
# shuffle
#
# Epoch 33: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 426ms/step - loss: 707.9584 - mae: 20.9159 - val_loss: 49.3788 - val_mae: 5.4276
# Epoch 34/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - loss: 583.9388 - mae: 19.1932shuffle
# shuffle
#
# Epoch 34: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 425ms/step - loss: 585.7329 - mae: 19.2206 - val_loss: 40.6939 - val_mae: 4.9657
# Epoch 35/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - loss: 616.0583 - mae: 19.4864shuffle
# shuffle
#
# Epoch 35: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 426ms/step - loss: 616.3282 - mae: 19.5013 - val_loss: 53.8182 - val_mae: 5.7098
# Epoch 36/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - loss: 618.2067 - mae: 19.6254shuffle
# shuffle
#
# Epoch 36: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 427ms/step - loss: 617.5133 - mae: 19.6147 - val_loss: 60.0566 - val_mae: 6.0367
# Epoch 37/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - loss: 668.1265 - mae: 20.3028shuffle
# shuffle
#
# Epoch 37: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 426ms/step - loss: 667.4962 - mae: 20.2908 - val_loss: 41.3821 - val_mae: 4.9884
# Epoch 38/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - loss: 683.3085 - mae: 20.7603shuffle
# shuffle
#
# Epoch 38: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 428ms/step - loss: 681.9695 - mae: 20.7340 - val_loss: 41.5102 - val_mae: 4.9733
# Epoch 39/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - loss: 614.1483 - mae: 19.5757shuffle
# shuffle
#
# Epoch 39: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 427ms/step - loss: 612.7941 - mae: 19.5555 - val_loss: 36.8693 - val_mae: 4.7851
# Epoch 40/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - loss: 645.1576 - mae: 20.0562shuffle
# shuffle
#
# Epoch 40: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 427ms/step - loss: 644.4161 - mae: 20.0484 - val_loss: 33.7430 - val_mae: 4.5563
# Epoch 41/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - loss: 606.9395 - mae: 19.5102shuffle
# shuffle
#
# Epoch 41: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 427ms/step - loss: 605.7589 - mae: 19.4919 - val_loss: 64.7507 - val_mae: 6.2823
# Epoch 42/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - loss: 636.8393 - mae: 20.0854shuffle
# shuffle
#
# Epoch 42: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 427ms/step - loss: 635.2153 - mae: 20.0622 - val_loss: 100.2690 - val_mae: 8.0398
# Epoch 43/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - loss: 670.7738 - mae: 20.4453shuffle
# shuffle
#
# Epoch 43: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 429ms/step - loss: 669.7367 - mae: 20.4237 - val_loss: 41.2296 - val_mae: 5.0815
# Epoch 44/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - loss: 668.7833 - mae: 20.3103shuffle
# shuffle
#
# Epoch 44: val_loss did not improve from 33.72350
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 428ms/step - loss: 667.5983 - mae: 20.2882 - val_loss: 34.8180 - val_mae: 4.5576
# Epoch 45/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - loss: 671.4003 - mae: 20.5302shuffle
# shuffle
#
# Epoch 45: val_loss improved from 33.72350 to 33.62780, saving model to /content/drive/MyDrive/Dataset/aspine20241201.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - loss: 669.7200 - mae: 20.5015 - val_loss: 33.6278 - val_mae: 4.4923
# Epoch 46/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - loss: 622.0323 - mae: 19.7475shuffle
# shuffle
#
# Epoch 46: val_loss did not improve from 33.62780
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 426ms/step - loss: 622.3328 - mae: 19.7433 - val_loss: 83.3156 - val_mae: 7.4302
# Epoch 47/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - loss: 609.8571 - mae: 19.6689shuffle
# shuffle
#
# Epoch 47: val_loss did not improve from 33.62780
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 427ms/step - loss: 609.4423 - mae: 19.6562 - val_loss: 89.0144 - val_mae: 7.7261
# Epoch 48/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - loss: 612.0844 - mae: 19.7335shuffle
# shuffle
#
# Epoch 48: val_loss did not improve from 33.62780
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 10s 430ms/step - loss: 612.9703 - mae: 19.7441 - val_loss: 38.8858 - val_mae: 4.8443
# Epoch 49/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - loss: 610.6494 - mae: 19.5957shuffle
# shuffle
#
# Epoch 49: val_loss did not improve from 33.62780
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 435ms/step - loss: 612.1689 - mae: 19.6232 - val_loss: 35.8324 - val_mae: 4.7060
# Epoch 50/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - loss: 629.1403 - mae: 19.8437shuffle
# shuffle
#
# Epoch 50: val_loss did not improve from 33.62780
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 436ms/step - loss: 630.0816 - mae: 19.8650 - val_loss: 76.9395 - val_mae: 7.0181
# Epoch 51/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 659.7975 - mae: 20.2144shuffle
# shuffle
#
# Epoch 51: val_loss did not improve from 33.62780
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 660.3539 - mae: 20.2237 - val_loss: 82.5063 - val_mae: 7.2686
# Epoch 52/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - loss: 595.9451 - mae: 19.2655shuffle
# shuffle
#
# Epoch 52: val_loss did not improve from 33.62780
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 441ms/step - loss: 595.6740 - mae: 19.2652 - val_loss: 60.5846 - val_mae: 6.0790
# Epoch 53/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - loss: 616.1310 - mae: 19.6315shuffle
# shuffle
#
# Epoch 53: val_loss did not improve from 33.62780
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 447ms/step - loss: 616.4655 - mae: 19.6441 - val_loss: 47.6259 - val_mae: 5.3651
# Epoch 54/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - loss: 634.4078 - mae: 19.9828shuffle
# shuffle
#
# Epoch 54: val_loss did not improve from 33.62780
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 451ms/step - loss: 634.6992 - mae: 19.9851 - val_loss: 38.9573 - val_mae: 4.8362
# Epoch 55/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - loss: 628.6539 - mae: 19.8523shuffle
# shuffle
#
# Epoch 55: val_loss did not improve from 33.62780
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 449ms/step - loss: 628.6391 - mae: 19.8498 - val_loss: 35.3802 - val_mae: 4.6585
# Epoch 56/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - loss: 605.4054 - mae: 19.4485shuffle
# shuffle
#
# Epoch 56: val_loss improved from 33.62780 to 32.88855, saving model to /content/drive/MyDrive/Dataset/aspine20241201.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - loss: 606.0477 - mae: 19.4598 - val_loss: 32.8886 - val_mae: 4.5055
# Epoch 57/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - loss: 608.9758 - mae: 19.5365shuffle
# shuffle
#
# Epoch 57: val_loss did not improve from 32.88855
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 442ms/step - loss: 607.6586 - mae: 19.5165 - val_loss: 33.3944 - val_mae: 4.5174
# Epoch 58/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 639.5735 - mae: 19.9939shuffle
# shuffle
#
# Epoch 58: val_loss did not improve from 32.88855
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 639.3807 - mae: 19.9977 - val_loss: 54.6247 - val_mae: 5.7804
# Epoch 59/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - loss: 637.9114 - mae: 20.0641shuffle
# shuffle
#
# Epoch 59: val_loss did not improve from 32.88855
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 440ms/step - loss: 636.4140 - mae: 20.0409 - val_loss: 40.0990 - val_mae: 4.9071
# Epoch 60/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - loss: 626.4700 - mae: 19.7518shuffle
# shuffle
#
# Epoch 60: val_loss did not improve from 32.88855
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 442ms/step - loss: 626.0598 - mae: 19.7483 - val_loss: 72.2815 - val_mae: 6.8170
# Epoch 61/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - loss: 577.7575 - mae: 19.1424shuffle
# shuffle
#
# Epoch 61: val_loss did not improve from 32.88855
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 449ms/step - loss: 578.9985 - mae: 19.1608 - val_loss: 34.3695 - val_mae: 4.6554
# Epoch 62/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - loss: 648.4286 - mae: 19.9847shuffle
# shuffle
#
# Epoch 62: val_loss did not improve from 32.88855
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 447ms/step - loss: 648.2867 - mae: 19.9904 - val_loss: 37.6338 - val_mae: 4.8446
# Epoch 63/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - loss: 636.2758 - mae: 20.0733shuffle
# shuffle
#
# Epoch 63: val_loss did not improve from 32.88855
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 446ms/step - loss: 632.7523 - mae: 20.0111 - val_loss: 125.1214 - val_mae: 9.1409
# Epoch 64/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - loss: 649.4673 - mae: 20.1950shuffle
# shuffle
#
# Epoch 64: val_loss did not improve from 32.88855
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 445ms/step - loss: 647.4390 - mae: 20.1659 - val_loss: 99.0374 - val_mae: 8.1174
# Epoch 65/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - loss: 637.9745 - mae: 19.9868shuffle
# shuffle
#
# Epoch 65: val_loss did not improve from 32.88855
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 445ms/step - loss: 635.4088 - mae: 19.9524 - val_loss: 44.8794 - val_mae: 5.2656
# Epoch 66/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - loss: 595.1046 - mae: 19.3992shuffle
# shuffle
#
# Epoch 66: val_loss did not improve from 32.88855
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 440ms/step - loss: 595.0870 - mae: 19.3953 - val_loss: 34.0706 - val_mae: 4.6106
# Epoch 67/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 586.8754 - mae: 19.0835shuffle
# shuffle
#
# Epoch 67: val_loss improved from 32.88855 to 32.51659, saving model to /content/drive/MyDrive/Dataset/aspine20241201.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - loss: 586.9015 - mae: 19.0823 - val_loss: 32.5166 - val_mae: 4.4764
# Epoch 68/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - loss: 585.9296 - mae: 19.2599shuffle
# shuffle
#
# Epoch 68: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 8s 431ms/step - loss: 585.8389 - mae: 19.2516 - val_loss: 51.2912 - val_mae: 5.6106
# Epoch 69/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - loss: 641.8550 - mae: 19.9048shuffle
# shuffle
#
# Epoch 69: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - loss: 641.2280 - mae: 19.9003 - val_loss: 35.9107 - val_mae: 4.6743
# Epoch 70/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 613.6075 - mae: 19.5600shuffle
# shuffle
#
# Epoch 70: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 439ms/step - loss: 612.9312 - mae: 19.5509 - val_loss: 36.1436 - val_mae: 4.7541
# Epoch 71/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - loss: 587.1644 - mae: 19.1936shuffle
# shuffle
#
# Epoch 71: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 443ms/step - loss: 588.4579 - mae: 19.2173 - val_loss: 49.8254 - val_mae: 5.6227
# Epoch 72/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - loss: 603.5999 - mae: 19.3169shuffle
# shuffle
#
# Epoch 72: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 446ms/step - loss: 603.5150 - mae: 19.3229 - val_loss: 38.0908 - val_mae: 4.8101
# Epoch 73/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - loss: 656.1230 - mae: 20.1990shuffle
# shuffle
#
# Epoch 73: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 449ms/step - loss: 653.7070 - mae: 20.1626 - val_loss: 60.2258 - val_mae: 6.1500
# Epoch 74/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - loss: 622.3380 - mae: 19.6689shuffle
# shuffle
#
# Epoch 74: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 463ms/step - loss: 621.8035 - mae: 19.6599 - val_loss: 108.2739 - val_mae: 8.5699
# Epoch 75/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - loss: 598.0792 - mae: 19.4364shuffle
# shuffle
#
# Epoch 75: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 449ms/step - loss: 599.4581 - mae: 19.4573 - val_loss: 53.7148 - val_mae: 5.7622
# Epoch 76/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - loss: 606.1001 - mae: 19.5401shuffle
# shuffle
#
# Epoch 76: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 446ms/step - loss: 606.5519 - mae: 19.5433 - val_loss: 79.3092 - val_mae: 7.1540
# Epoch 77/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - loss: 637.6423 - mae: 20.0388shuffle
# shuffle
#
# Epoch 77: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 441ms/step - loss: 637.1982 - mae: 20.0327 - val_loss: 33.0591 - val_mae: 4.4657
# Epoch 78/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 582.4239 - mae: 19.2039shuffle
# shuffle
#
# Epoch 78: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 440ms/step - loss: 582.6807 - mae: 19.2042 - val_loss: 34.8567 - val_mae: 4.6506
# Epoch 79/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 581.8542 - mae: 19.1222shuffle
# shuffle
#
# Epoch 79: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 582.1141 - mae: 19.1276 - val_loss: 35.3620 - val_mae: 4.6945
# Epoch 80/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - loss: 572.5873 - mae: 18.9607shuffle
# shuffle
#
# Epoch 80: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 445ms/step - loss: 573.3604 - mae: 18.9787 - val_loss: 36.4301 - val_mae: 4.7468
# Epoch 81/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - loss: 578.1313 - mae: 19.1378shuffle
# shuffle
#
# Epoch 81: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 436ms/step - loss: 577.9622 - mae: 19.1335 - val_loss: 49.3415 - val_mae: 5.5574
# Epoch 82/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - loss: 620.2946 - mae: 19.7944shuffle
# shuffle
#
# Epoch 82: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 435ms/step - loss: 619.5784 - mae: 19.7777 - val_loss: 61.3161 - val_mae: 6.1880
# Epoch 83/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - loss: 567.9833 - mae: 18.8816shuffle
# shuffle
#
# Epoch 83: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 436ms/step - loss: 569.4553 - mae: 18.9027 - val_loss: 41.9492 - val_mae: 5.0054
# Epoch 84/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - loss: 628.4468 - mae: 19.8772shuffle
# shuffle
#
# Epoch 84: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 435ms/step - loss: 625.8684 - mae: 19.8343 - val_loss: 64.8370 - val_mae: 6.3136
# Epoch 85/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 563.5095 - mae: 18.7945shuffle
# shuffle
#
# Epoch 85: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - loss: 564.5363 - mae: 18.8128 - val_loss: 47.1440 - val_mae: 5.4196
# Epoch 86/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 626.2823 - mae: 19.8114shuffle
# shuffle
#
# Epoch 86: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 624.2668 - mae: 19.7854 - val_loss: 55.1054 - val_mae: 5.8531
# Epoch 87/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 633.7992 - mae: 19.8442shuffle
# shuffle
#
# Epoch 87: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 440ms/step - loss: 630.9918 - mae: 19.7969 - val_loss: 88.3886 - val_mae: 7.5676
# Epoch 88/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 594.5927 - mae: 19.1422shuffle
# shuffle
#
# Epoch 88: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 440ms/step - loss: 592.7657 - mae: 19.1188 - val_loss: 36.7422 - val_mae: 4.8123
# Epoch 89/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 616.6829 - mae: 19.9310shuffle
# shuffle
#
# Epoch 89: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 440ms/step - loss: 614.3205 - mae: 19.8852 - val_loss: 58.7805 - val_mae: 6.0527
# Epoch 90/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - loss: 551.9543 - mae: 18.7060shuffle
# shuffle
#
# Epoch 90: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 440ms/step - loss: 553.9895 - mae: 18.7362 - val_loss: 34.4060 - val_mae: 4.5800
# Epoch 91/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 578.1971 - mae: 19.1752shuffle
# shuffle
#
# Epoch 91: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 439ms/step - loss: 578.4446 - mae: 19.1767 - val_loss: 35.2880 - val_mae: 4.5817
# Epoch 92/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 656.0775 - mae: 20.1806shuffle
# shuffle
#
# Epoch 92: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 654.2023 - mae: 20.1562 - val_loss: 46.1495 - val_mae: 5.3446
# Epoch 93/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 560.8647 - mae: 18.6839shuffle
# shuffle
#
# Epoch 93: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 562.4670 - mae: 18.7048 - val_loss: 38.5480 - val_mae: 4.8269
# Epoch 94/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - loss: 571.0931 - mae: 18.9121shuffle
# shuffle
#
# Epoch 94: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 450ms/step - loss: 571.6852 - mae: 18.9190 - val_loss: 43.6377 - val_mae: 5.1183
# Epoch 95/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - loss: 605.4124 - mae: 19.4761shuffle
# shuffle
#
# Epoch 95: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 447ms/step - loss: 605.1479 - mae: 19.4611 - val_loss: 70.8240 - val_mae: 6.7794
# Epoch 96/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 595.2133 - mae: 19.1913shuffle
# shuffle
#
# Epoch 96: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - loss: 594.9904 - mae: 19.1981 - val_loss: 67.1990 - val_mae: 6.5436
# Epoch 97/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 591.4517 - mae: 19.3097shuffle
# shuffle
#
# Epoch 97: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - loss: 591.6721 - mae: 19.3109 - val_loss: 98.6074 - val_mae: 8.0420
# Epoch 98/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 631.3890 - mae: 19.8668shuffle
# shuffle
#
# Epoch 98: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - loss: 630.5257 - mae: 19.8513 - val_loss: 61.0199 - val_mae: 6.1726
# Epoch 99/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 568.1629 - mae: 18.8510shuffle
# shuffle
#
# Epoch 99: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - loss: 568.9130 - mae: 18.8639 - val_loss: 39.1866 - val_mae: 4.8569
# Epoch 100/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 619.7399 - mae: 19.6015shuffle
# shuffle
#
# Epoch 100: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 620.4228 - mae: 19.6052 - val_loss: 34.5828 - val_mae: 4.5889
# Epoch 101/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 565.0424 - mae: 18.9732shuffle
# shuffle
#
# Epoch 101: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 564.8549 - mae: 18.9657 - val_loss: 36.2779 - val_mae: 4.7034
# Epoch 102/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - loss: 592.1539 - mae: 19.1942shuffle
# shuffle
#
# Epoch 102: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 448ms/step - loss: 593.9842 - mae: 19.2181 - val_loss: 43.9947 - val_mae: 5.1143
# Epoch 103/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 543.3396 - mae: 18.6497shuffle
# shuffle
#
# Epoch 103: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 440ms/step - loss: 545.9002 - mae: 18.6858 - val_loss: 89.2191 - val_mae: 7.6062
# Epoch 104/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 585.1971 - mae: 19.1330shuffle
# shuffle
#
# Epoch 104: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 585.0406 - mae: 19.1280 - val_loss: 62.3179 - val_mae: 6.1801
# Epoch 105/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - loss: 626.1755 - mae: 19.6571shuffle
# shuffle
#
# Epoch 105: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 449ms/step - loss: 624.8714 - mae: 19.6344 - val_loss: 41.3115 - val_mae: 4.9348
# Epoch 106/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - loss: 532.5616 - mae: 18.4053shuffle
# shuffle
#
# Epoch 106: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 440ms/step - loss: 533.0450 - mae: 18.4124 - val_loss: 49.0709 - val_mae: 5.4369
# Epoch 107/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 568.0999 - mae: 18.8791shuffle
# shuffle
#
# Epoch 107: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 568.3170 - mae: 18.8855 - val_loss: 101.7837 - val_mae: 8.1436
# Epoch 108/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 648.8005 - mae: 20.1555shuffle
# shuffle
#
# Epoch 108: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 647.8744 - mae: 20.1462 - val_loss: 71.7082 - val_mae: 6.7359
# Epoch 109/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 599.0596 - mae: 19.5122shuffle
# shuffle
#
# Epoch 109: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 598.1390 - mae: 19.4864 - val_loss: 73.3994 - val_mae: 6.8540
# Epoch 110/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - loss: 566.6249 - mae: 18.8060shuffle
# shuffle
#
# Epoch 110: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 440ms/step - loss: 567.5716 - mae: 18.8265 - val_loss: 53.5398 - val_mae: 5.6506
# Epoch 111/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 547.7117 - mae: 18.5484shuffle
# shuffle
#
# Epoch 111: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 439ms/step - loss: 547.7525 - mae: 18.5473 - val_loss: 33.9566 - val_mae: 4.5333
# Epoch 112/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 623.4723 - mae: 19.6291shuffle
# shuffle
#
# Epoch 112: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 622.0474 - mae: 19.6111 - val_loss: 34.3454 - val_mae: 4.5727
# Epoch 113/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 613.3986 - mae: 19.6026shuffle
# shuffle
#
# Epoch 113: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 613.5480 - mae: 19.6023 - val_loss: 41.1482 - val_mae: 5.0052
# Epoch 114/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - loss: 571.5784 - mae: 18.9428shuffle
# shuffle
#
# Epoch 114: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 449ms/step - loss: 571.1996 - mae: 18.9347 - val_loss: 49.0692 - val_mae: 5.4966
# Epoch 115/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 553.8979 - mae: 18.6483shuffle
# shuffle
#
# Epoch 115: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 554.2452 - mae: 18.6560 - val_loss: 111.4805 - val_mae: 8.5792
# Epoch 116/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 597.2136 - mae: 19.3197shuffle
# shuffle
#
# Epoch 116: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - loss: 594.0917 - mae: 19.2674 - val_loss: 50.9124 - val_mae: 5.4968
# Epoch 117/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 526.2639 - mae: 18.1541shuffle
# shuffle
#
# Epoch 117: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 527.5302 - mae: 18.1758 - val_loss: 40.4397 - val_mae: 4.9122
# Epoch 118/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 532.5051 - mae: 18.2939shuffle
# shuffle
#
# Epoch 118: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - loss: 535.3850 - mae: 18.3416 - val_loss: 37.7242 - val_mae: 4.8030
# Epoch 119/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - loss: 588.2462 - mae: 19.1092shuffle
# shuffle
#
# Epoch 119: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 436ms/step - loss: 587.5896 - mae: 19.1036 - val_loss: 46.5437 - val_mae: 5.3819
# Epoch 120/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 578.9998 - mae: 19.0355shuffle
# shuffle
#
# Epoch 120: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 578.0648 - mae: 19.0173 - val_loss: 34.1956 - val_mae: 4.6104
# Epoch 121/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 548.5570 - mae: 18.7421shuffle
# shuffle
#
# Epoch 121: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - loss: 548.9270 - mae: 18.7434 - val_loss: 46.7178 - val_mae: 5.2818
# Epoch 122/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 556.7448 - mae: 18.7293shuffle
# shuffle
#
# Epoch 122: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 436ms/step - loss: 556.3168 - mae: 18.7243 - val_loss: 33.5374 - val_mae: 4.5480
# Epoch 123/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 532.6152 - mae: 18.3413shuffle
# shuffle
#
# Epoch 123: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - loss: 532.8774 - mae: 18.3448 - val_loss: 46.9474 - val_mae: 5.3779
# Epoch 124/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 543.7217 - mae: 18.5461shuffle
# shuffle
#
# Epoch 124: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 545.9979 - mae: 18.5802 - val_loss: 34.9608 - val_mae: 4.6731
# Epoch 125/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 524.9675 - mae: 18.1994shuffle
# shuffle
#
# Epoch 125: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 525.0372 - mae: 18.1986 - val_loss: 34.8084 - val_mae: 4.6297
# Epoch 126/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 597.3976 - mae: 19.3732shuffle
# shuffle
#
# Epoch 126: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 439ms/step - loss: 595.8876 - mae: 19.3543 - val_loss: 64.0273 - val_mae: 6.2452
# Epoch 127/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 555.6669 - mae: 18.6736shuffle
# shuffle
#
# Epoch 127: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 555.9896 - mae: 18.6846 - val_loss: 108.6236 - val_mae: 8.4766
# Epoch 128/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 588.5953 - mae: 19.0680shuffle
# shuffle
#
# Epoch 128: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 588.3564 - mae: 19.0707 - val_loss: 59.0896 - val_mae: 6.0198
# Epoch 129/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 543.4894 - mae: 18.4237shuffle
# shuffle
#
# Epoch 129: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 439ms/step - loss: 544.1271 - mae: 18.4430 - val_loss: 55.5354 - val_mae: 5.7876
# Epoch 130/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 563.9661 - mae: 18.6873shuffle
# shuffle
#
# Epoch 130: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 563.8181 - mae: 18.6899 - val_loss: 63.3722 - val_mae: 6.2579
# Epoch 131/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 553.4481 - mae: 18.6277shuffle
# shuffle
#
# Epoch 131: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 555.5648 - mae: 18.6627 - val_loss: 37.0290 - val_mae: 4.7737
# Epoch 132/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 580.6395 - mae: 19.1638shuffle
# shuffle
#
# Epoch 132: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 581.5132 - mae: 19.1753 - val_loss: 36.9906 - val_mae: 4.8450
# Epoch 133/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 585.7333 - mae: 19.0010shuffle
# shuffle
#
# Epoch 133: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 440ms/step - loss: 584.1913 - mae: 18.9762 - val_loss: 70.8414 - val_mae: 6.6579
# Epoch 134/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 543.6411 - mae: 18.5432shuffle
# shuffle
#
# Epoch 134: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 543.1489 - mae: 18.5359 - val_loss: 54.4275 - val_mae: 5.7933
# Epoch 135/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 571.3227 - mae: 18.8660shuffle
# shuffle
#
# Epoch 135: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 439ms/step - loss: 573.3876 - mae: 18.8907 - val_loss: 41.8873 - val_mae: 5.0081
# Epoch 136/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 550.2864 - mae: 18.5005shuffle
# shuffle
#
# Epoch 136: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 439ms/step - loss: 551.6566 - mae: 18.5244 - val_loss: 44.5035 - val_mae: 5.2033
# Epoch 137/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 542.3876 - mae: 18.4951shuffle
# shuffle
#
# Epoch 137: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 439ms/step - loss: 543.9825 - mae: 18.5197 - val_loss: 69.6756 - val_mae: 6.7084
# Epoch 138/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 582.7054 - mae: 19.0372shuffle
# shuffle
#
# Epoch 138: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 579.5845 - mae: 18.9851 - val_loss: 152.0366 - val_mae: 10.3831
# Epoch 139/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 637.0330 - mae: 19.6680shuffle
# shuffle
#
# Epoch 139: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 635.6503 - mae: 19.6526 - val_loss: 35.9750 - val_mae: 4.6418
# Epoch 140/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 570.0892 - mae: 18.9583shuffle
# shuffle
#
# Epoch 140: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 567.9393 - mae: 18.9233 - val_loss: 32.9434 - val_mae: 4.5387
# Epoch 141/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 566.6222 - mae: 18.8300shuffle
# shuffle
#
# Epoch 141: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 566.1521 - mae: 18.8252 - val_loss: 39.2288 - val_mae: 4.9027
# Epoch 142/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 521.7128 - mae: 18.1455shuffle
# shuffle
#
# Epoch 142: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 523.4709 - mae: 18.1761 - val_loss: 38.8204 - val_mae: 4.9542
# Epoch 143/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 541.9054 - mae: 18.5764shuffle
# shuffle
#
# Epoch 143: val_loss did not improve from 32.51659
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 439ms/step - loss: 541.9694 - mae: 18.5755 - val_loss: 40.2654 - val_mae: 4.9180
# Epoch 144/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 564.2612 - mae: 18.7340shuffle
# shuffle
#
# Epoch 144: val_loss improved from 32.51659 to 32.12401, saving model to /content/drive/MyDrive/Dataset/aspine20241201.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - loss: 564.0206 - mae: 18.7260 - val_loss: 32.1240 - val_mae: 4.4351
# Epoch 145/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - loss: 531.2463 - mae: 18.3194shuffle
# shuffle
#
# Epoch 145: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 432ms/step - loss: 532.3251 - mae: 18.3377 - val_loss: 35.3781 - val_mae: 4.6207
# Epoch 146/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - loss: 531.5627 - mae: 18.3729shuffle
# shuffle
#
# Epoch 146: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 436ms/step - loss: 532.8511 - mae: 18.3928 - val_loss: 55.9249 - val_mae: 5.9736
# Epoch 147/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - loss: 537.1968 - mae: 18.5376shuffle
# shuffle
#
# Epoch 147: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 440ms/step - loss: 537.0833 - mae: 18.5277 - val_loss: 37.7450 - val_mae: 4.7436
# Epoch 148/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - loss: 537.3631 - mae: 18.3616shuffle
# shuffle
#
# Epoch 148: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 444ms/step - loss: 538.3215 - mae: 18.3807 - val_loss: 35.6252 - val_mae: 4.6387
# Epoch 149/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - loss: 550.4500 - mae: 18.5097shuffle
# shuffle
#
# Epoch 149: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 447ms/step - loss: 551.5982 - mae: 18.5274 - val_loss: 41.2111 - val_mae: 5.0853
# Epoch 150/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - loss: 623.6240 - mae: 19.7624shuffle
# shuffle
#
# Epoch 150: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 447ms/step - loss: 621.6689 - mae: 19.7367 - val_loss: 58.9289 - val_mae: 6.1470
# Epoch 151/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step - loss: 565.0883 - mae: 18.8127shuffle
# shuffle
#
# Epoch 151: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 458ms/step - loss: 564.9005 - mae: 18.8117 - val_loss: 40.6644 - val_mae: 4.9857
# Epoch 152/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - loss: 538.5833 - mae: 18.3574shuffle
# shuffle
#
# Epoch 152: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 443ms/step - loss: 540.0941 - mae: 18.3825 - val_loss: 34.8353 - val_mae: 4.6391
# Epoch 153/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - loss: 556.0644 - mae: 18.7716shuffle
# shuffle
#
# Epoch 153: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 442ms/step - loss: 557.0039 - mae: 18.7786 - val_loss: 35.8209 - val_mae: 4.6872
# Epoch 154/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - loss: 529.6932 - mae: 18.1798shuffle
# shuffle
#
# Epoch 154: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 439ms/step - loss: 529.4648 - mae: 18.1781 - val_loss: 78.6930 - val_mae: 7.0981
# Epoch 155/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 559.6569 - mae: 18.8741shuffle
# shuffle
#
# Epoch 155: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - loss: 561.0255 - mae: 18.8865 - val_loss: 69.5473 - val_mae: 6.6592
# Epoch 156/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - loss: 570.3819 - mae: 18.9555shuffle
# shuffle
#
# Epoch 156: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 435ms/step - loss: 571.6858 - mae: 18.9724 - val_loss: 43.0932 - val_mae: 5.1011
# Epoch 157/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 536.0496 - mae: 18.3679shuffle
# shuffle
#
# Epoch 157: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 436ms/step - loss: 535.0278 - mae: 18.3535 - val_loss: 39.3094 - val_mae: 4.8584
# Epoch 158/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - loss: 558.2278 - mae: 18.7030shuffle
# shuffle
#
# Epoch 158: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 436ms/step - loss: 558.8702 - mae: 18.7149 - val_loss: 32.3961 - val_mae: 4.4909
# Epoch 159/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 582.4897 - mae: 19.0749shuffle
# shuffle
#
# Epoch 159: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 436ms/step - loss: 581.4125 - mae: 19.0656 - val_loss: 37.5703 - val_mae: 4.8525
# Epoch 160/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - loss: 574.1351 - mae: 18.9857shuffle
# shuffle
#
# Epoch 160: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 436ms/step - loss: 573.1400 - mae: 18.9636 - val_loss: 39.2822 - val_mae: 4.8879
# Epoch 161/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 512.8086 - mae: 17.9234shuffle
# shuffle
#
# Epoch 161: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 514.1766 - mae: 17.9449 - val_loss: 41.9177 - val_mae: 5.0490
# Epoch 162/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 532.6028 - mae: 18.1746shuffle
# shuffle
#
# Epoch 162: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 533.2986 - mae: 18.1908 - val_loss: 34.9911 - val_mae: 4.6440
# Epoch 163/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 529.3013 - mae: 18.1763shuffle
# shuffle
#
# Epoch 163: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 439ms/step - loss: 531.8245 - mae: 18.2130 - val_loss: 33.8379 - val_mae: 4.5655
# Epoch 164/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 550.6347 - mae: 18.6158shuffle
# shuffle
#
# Epoch 164: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 551.2947 - mae: 18.6234 - val_loss: 70.7647 - val_mae: 6.6516
# Epoch 165/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 537.2117 - mae: 18.3175shuffle
# shuffle
#
# Epoch 165: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 439ms/step - loss: 539.0836 - mae: 18.3486 - val_loss: 72.9205 - val_mae: 6.8680
# Epoch 166/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 528.6284 - mae: 18.3175shuffle
# shuffle
#
# Epoch 166: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 439ms/step - loss: 527.5682 - mae: 18.2952 - val_loss: 37.8311 - val_mae: 4.8001
# Epoch 167/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 614.4696 - mae: 19.3171shuffle
# shuffle
#
# Epoch 167: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 439ms/step - loss: 610.5533 - mae: 19.2707 - val_loss: 32.5014 - val_mae: 4.4799
# Epoch 168/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 544.8130 - mae: 18.4322shuffle
# shuffle
#
# Epoch 168: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 439ms/step - loss: 544.8073 - mae: 18.4373 - val_loss: 65.9180 - val_mae: 6.3874
# Epoch 169/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - loss: 506.8296 - mae: 17.7733shuffle
# shuffle
#
# Epoch 169: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 436ms/step - loss: 508.8802 - mae: 17.8103 - val_loss: 37.4513 - val_mae: 4.7243
# Epoch 170/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - loss: 568.0463 - mae: 18.8313shuffle
# shuffle
#
# Epoch 170: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 450ms/step - loss: 569.1504 - mae: 18.8453 - val_loss: 129.9386 - val_mae: 9.3115
# Epoch 171/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - loss: 598.7578 - mae: 19.3560shuffle
# shuffle
#
# Epoch 171: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 436ms/step - loss: 598.3668 - mae: 19.3511 - val_loss: 33.9563 - val_mae: 4.5796
# Epoch 172/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 525.0325 - mae: 18.1865shuffle
# shuffle
#
# Epoch 172: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 525.4895 - mae: 18.1897 - val_loss: 33.7843 - val_mae: 4.5515
# Epoch 173/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - loss: 587.3066 - mae: 19.3023shuffle
# shuffle
#
# Epoch 173: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 436ms/step - loss: 584.4165 - mae: 19.2485 - val_loss: 64.4669 - val_mae: 6.3360
# Epoch 174/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 510.2530 - mae: 17.8988shuffle
# shuffle
#
# Epoch 174: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 511.7078 - mae: 17.9227 - val_loss: 36.2646 - val_mae: 4.6814
# Epoch 175/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 528.4922 - mae: 18.2733shuffle
# shuffle
#
# Epoch 175: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - loss: 529.1974 - mae: 18.2793 - val_loss: 48.2072 - val_mae: 5.3765
# Epoch 176/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 545.7363 - mae: 18.3872shuffle
# shuffle
#
# Epoch 176: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - loss: 545.1130 - mae: 18.3794 - val_loss: 35.9511 - val_mae: 4.6184
# Epoch 177/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 494.9221 - mae: 17.5088shuffle
# shuffle
#
# Epoch 177: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - loss: 495.5394 - mae: 17.5249 - val_loss: 47.8839 - val_mae: 5.3191
# Epoch 178/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 533.5736 - mae: 18.2918shuffle
# shuffle
#
# Epoch 178: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 534.0937 - mae: 18.3066 - val_loss: 33.1070 - val_mae: 4.5170
# Epoch 179/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 539.8619 - mae: 18.3375shuffle
# shuffle
#
# Epoch 179: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 540.2393 - mae: 18.3422 - val_loss: 89.4790 - val_mae: 7.5652
# Epoch 180/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 542.0380 - mae: 18.3788shuffle
# shuffle
#
# Epoch 180: val_loss did not improve from 32.12401
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 540.7717 - mae: 18.3653 - val_loss: 38.1444 - val_mae: 4.7682
# Epoch 181/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 530.7179 - mae: 18.2219shuffle
# shuffle
#
# ...
# Epoch 318/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - loss: 465.3381 - mae: 17.0640shuffle
# shuffle
#
# Epoch 318: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 436ms/step - loss: 466.0553 - mae: 17.0756 - val_loss: 39.9587 - val_mae: 4.9196
# Epoch 319/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 429.8151 - mae: 16.4923shuffle
# shuffle
#
# Epoch 319: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - loss: 431.0616 - mae: 16.5149 - val_loss: 32.7273 - val_mae: 4.4530
# Epoch 320/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 424.5916 - mae: 16.2834shuffle
# shuffle
#
# Epoch 320: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - loss: 425.7784 - mae: 16.2984 - val_loss: 32.5967 - val_mae: 4.4768
# Epoch 321/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 482.1567 - mae: 17.3598shuffle
# shuffle
#
# Epoch 321: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - loss: 482.7113 - mae: 17.3720 - val_loss: 33.7270 - val_mae: 4.6003
# Epoch 322/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 464.2917 - mae: 16.8658shuffle
# shuffle
#
# Epoch 322: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - loss: 465.0892 - mae: 16.8838 - val_loss: 37.5415 - val_mae: 4.7507
# Epoch 323/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - loss: 471.0663 - mae: 17.0995shuffle
# shuffle
#
# Epoch 323: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 447ms/step - loss: 470.9182 - mae: 17.0922 - val_loss: 54.2935 - val_mae: 5.9260
# Epoch 324/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 492.0246 - mae: 17.5143shuffle
# shuffle
#
# Epoch 324: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - loss: 492.2705 - mae: 17.5179 - val_loss: 36.9337 - val_mae: 4.8287
# Epoch 325/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 467.7096 - mae: 16.9958shuffle
# shuffle
#
# Epoch 325: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 467.4023 - mae: 16.9862 - val_loss: 35.2095 - val_mae: 4.6446
# Epoch 326/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 458.5176 - mae: 16.9204shuffle
# shuffle
#
# Epoch 326: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - loss: 457.9860 - mae: 16.9080 - val_loss: 103.8484 - val_mae: 8.2123
# Epoch 327/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 492.2549 - mae: 17.4415shuffle
# shuffle
#
# Epoch 327: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 439ms/step - loss: 492.3546 - mae: 17.4406 - val_loss: 88.4194 - val_mae: 7.5369
# Epoch 328/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - loss: 507.6260 - mae: 17.8446shuffle
# shuffle
#
# Epoch 328: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 439ms/step - loss: 507.1278 - mae: 17.8323 - val_loss: 38.5483 - val_mae: 4.8046
# Epoch 329/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - loss: 445.9216 - mae: 16.7387shuffle
# shuffle
#
# Epoch 329: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 447ms/step - loss: 446.3929 - mae: 16.7411 - val_loss: 35.5128 - val_mae: 4.7124
# Epoch 330/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 524.9189 - mae: 17.9891shuffle
# shuffle
#
# Epoch 330: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - loss: 522.9443 - mae: 17.9521 - val_loss: 33.4713 - val_mae: 4.5734
# Epoch 331/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - loss: 462.6018 - mae: 17.0784shuffle
# shuffle
#
# Epoch 331: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 448ms/step - loss: 465.0332 - mae: 17.1159 - val_loss: 60.0703 - val_mae: 6.0251
# Epoch 332/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 481.2049 - mae: 17.4148shuffle
# shuffle
#
# Epoch 332: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 480.6027 - mae: 17.4018 - val_loss: 64.0135 - val_mae: 6.3008
# Epoch 333/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 430.9310 - mae: 16.2889shuffle
# shuffle
#
# Epoch 333: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 432.3332 - mae: 16.3190 - val_loss: 155.2671 - val_mae: 10.2935
# Epoch 334/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 460.5529 - mae: 16.8833shuffle
# shuffle
#
# Epoch 334: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 462.3264 - mae: 16.9146 - val_loss: 97.6855 - val_mae: 7.9636
# Epoch 335/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 543.0237 - mae: 18.2102shuffle
# shuffle
#
# Epoch 335: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - loss: 539.3512 - mae: 18.1568 - val_loss: 67.7587 - val_mae: 6.4541
# Epoch 336/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 473.9146 - mae: 17.0046shuffle
# shuffle
#
# Epoch 336: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 472.3986 - mae: 16.9837 - val_loss: 66.9247 - val_mae: 6.3946
# Epoch 337/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 459.4916 - mae: 16.8635shuffle
# shuffle
#
# Epoch 337: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 436ms/step - loss: 459.8178 - mae: 16.8651 - val_loss: 40.7018 - val_mae: 4.8989
# Epoch 338/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - loss: 458.8313 - mae: 16.8013shuffle
# shuffle
#
# Epoch 338: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 435ms/step - loss: 459.3752 - mae: 16.8084 - val_loss: 64.4366 - val_mae: 6.2904
# Epoch 339/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 457.2968 - mae: 16.7792shuffle
# shuffle
#
# Epoch 339: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - loss: 458.9791 - mae: 16.8069 - val_loss: 56.0942 - val_mae: 5.8482
# Epoch 340/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - loss: 419.5313 - mae: 16.2018shuffle
# shuffle
#
# Epoch 340: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 436ms/step - loss: 419.1986 - mae: 16.2002 - val_loss: 62.6232 - val_mae: 6.2051
# Epoch 341/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - loss: 482.6257 - mae: 17.1616shuffle
# shuffle
#
# Epoch 341: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 435ms/step - loss: 483.0827 - mae: 17.1720 - val_loss: 58.8995 - val_mae: 5.9592
# Epoch 342/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 457.2203 - mae: 16.9773shuffle
# shuffle
#
# Epoch 342: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 436ms/step - loss: 457.2005 - mae: 16.9713 - val_loss: 33.8520 - val_mae: 4.5785
# Epoch 343/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - loss: 485.9909 - mae: 17.3475shuffle
# shuffle
#
# Epoch 343: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 436ms/step - loss: 485.9586 - mae: 17.3415 - val_loss: 35.1897 - val_mae: 4.6805
# Epoch 344/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 450.2641 - mae: 16.7942shuffle
# shuffle
#
# Epoch 344: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 436ms/step - loss: 449.0333 - mae: 16.7682 - val_loss: 64.3485 - val_mae: 6.3310
# Epoch 345/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - loss: 449.7845 - mae: 16.7791shuffle
# shuffle
#
# Epoch 345: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 435ms/step - loss: 449.6470 - mae: 16.7717 - val_loss: 53.3822 - val_mae: 5.7319
# Epoch 346/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 437.1312 - mae: 16.5608shuffle
# shuffle
#
# Epoch 346: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - loss: 438.7439 - mae: 16.5897 - val_loss: 36.2443 - val_mae: 4.6668
# Epoch 347/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - loss: 440.6345 - mae: 16.4041shuffle
# shuffle
#
# Epoch 347: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 436ms/step - loss: 440.1395 - mae: 16.3997 - val_loss: 35.0180 - val_mae: 4.6115
# Epoch 348/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - loss: 448.5743 - mae: 16.5864shuffle
# shuffle
#
# Epoch 348: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 435ms/step - loss: 448.0983 - mae: 16.5810 - val_loss: 47.8758 - val_mae: 5.3786
# Epoch 349/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - loss: 448.6135 - mae: 16.5444shuffle
# shuffle
#
# Epoch 349: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 436ms/step - loss: 448.3526 - mae: 16.5467 - val_loss: 63.3674 - val_mae: 6.3224
# Epoch 350/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 448.4120 - mae: 16.7655shuffle
# shuffle
#
# Epoch 350: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - loss: 448.9053 - mae: 16.7767 - val_loss: 44.7194 - val_mae: 5.1843
# Epoch 351/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 462.3843 - mae: 16.9832shuffle
# shuffle
#
# Epoch 351: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - loss: 460.8064 - mae: 16.9565 - val_loss: 35.0028 - val_mae: 4.5932
# Epoch 352/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 488.2126 - mae: 17.4968shuffle
# shuffle
#
# Epoch 352: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 487.3315 - mae: 17.4828 - val_loss: 35.9215 - val_mae: 4.6204
# Epoch 353/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - loss: 429.9808 - mae: 16.3179shuffle
# shuffle
#
# Epoch 353: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 447ms/step - loss: 430.3292 - mae: 16.3207 - val_loss: 106.2449 - val_mae: 8.4185
# Epoch 354/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 450.4529 - mae: 16.7569shuffle
# shuffle
#
# Epoch 354: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - loss: 451.7787 - mae: 16.7715 - val_loss: 86.7366 - val_mae: 7.5535
# Epoch 355/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 431.2838 - mae: 16.4276shuffle
# shuffle
#
# Epoch 355: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 432.7122 - mae: 16.4550 - val_loss: 48.4381 - val_mae: 5.4431
# Epoch 356/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 447.4619 - mae: 16.6088shuffle
# shuffle
#
# Epoch 356: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 447.8707 - mae: 16.6150 - val_loss: 31.7326 - val_mae: 4.4775
# Epoch 357/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 443.9110 - mae: 16.5439shuffle
# shuffle
#
# Epoch 357: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 443.9035 - mae: 16.5414 - val_loss: 32.9038 - val_mae: 4.5448
# Epoch 358/400
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - loss: 464.4265 - mae: 17.0612shuffle
# shuffle
#
# Epoch 358: val_loss did not improve from 30.39337
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - loss: 463.8229 - mae: 17.0537 - val_loss: 30.6659 - val_mae: 4.3525
# Epoch 359/400
# 11/12 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - loss: 435.1465 - mae: 16.3570
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-6d8c0496c9cc> in <cell line: 18>()
#      16 # reduce_lr_callback = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', factor=0.2, patience=3, min_lr=0.01)
#      17
# ---> 18 history = model.fit(train_generator,
#      19             validation_data=val_generator,
#      20             epochs=epoch_num,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     318                 for step, iterator in epoch_iterator.enumerate_epoch():
#     319                     callbacks.on_train_batch_begin(step)
# --> 320                     logs = self.train_function(iterator)
#     321                     logs = self._pythonify_logs(logs)
#     322                     callbacks.on_train_batch_end(step, logs)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1550     cancellation_context = cancellation.context()
#    1551     if cancellation_context is None:
# -> 1552       outputs = execute.execute(
#    1553           name.decode("utf-8"),
#    1554           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
mae = history.history['mae']
val_mae = history.history['val_mae']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(mae) + 1)

plt.plot(epochs, mae, label='Training mae')
plt.plot(epochs, val_mae, label='Validation mae')
plt.title('Training and validation mae')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
X_test, y_test= val_generator[0]
predictions = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step

# %%
index = np.random.randint(0,len(X_test))
#X, Y = X_test[index], predictions[index]
X, Y = X_test[index], predictions[index,:32]
show_tran_image(X,Y)

# %%
model.save("/content/drive/MyDrive/Dataset/densenet121.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
